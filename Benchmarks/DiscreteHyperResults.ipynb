# %%
import HyperOpt as run
results=run.Hyper_Opt(Continuous_on=False,Discrete_on=True)
# Out:
# Run # 0, 0, 0
# Fitness Convergence
# Program execution time was 2.014000.
# Run # 0, 0, 1
# Program execution time was 3.443000.
# Run # 0, 0, 2
# Generational Stall 49 9
# Program execution time was 2.676000.
# Run # 0, 0, 3
# Program execution time was 3.310000.
# Run # 0, 0, 4
# Program execution time was 3.289000.
# Run # 0, 0, 5
# Generational Stall 48 8
# Program execution time was 2.560000.
# Run # 0, 0, 6
# Program execution time was 3.246000.
# Run # 0, 0, 7
# Generational Stall 56 16
# Program execution time was 2.964000.
# Run # 0, 0, 8
# Program execution time was 3.541000.
# Run # 0, 0, 9
# Generational Stall 57 17
# Program execution time was 3.030000.
# Run # 0, 0, 10
# Program execution time was 3.389000.
# Run # 0, 0, 11
# Fitness Convergence
# Program execution time was 1.333000.
# Run # 0, 0, 12
# Program execution time was 3.284000.
# Run # 0, 0, 13
# Fitness Convergence
# Program execution time was 1.157000.
# Run # 0, 0, 14
# Fitness Convergence
# Program execution time was 1.690000.
# Run # 0, 0, 15
# Fitness Convergence
# Program execution time was 1.150000.
# Run # 0, 0, 16
# Program execution time was 3.308000.
# Run # 0, 0, 17
# Program execution time was 3.481000.
# Run # 0, 0, 18
# Generational Stall 65 25
# Program execution time was 3.425000.
# Run # 0, 0, 19
# Program execution time was 3.286000.
# Run # 0, 0, 20
# Generational Stall 55 15
# Program execution time was 2.864000.
# Run # 0, 0, 21
# Generational Stall 54 14
# Program execution time was 2.837000.
# Run # 0, 0, 22
# Program execution time was 3.277000.
# Run # 0, 0, 23
# Generational Stall 63 23
# Program execution time was 3.185000.
# Run # 0, 0, 24
# Generational Stall 65 25
# Program execution time was 3.238000.
# Run # 0, 1, 0
# Program execution time was 3.338000.
# Run # 0, 1, 1
# Generational Stall 53 13
# Program execution time was 2.805000.
# Run # 0, 1, 2
# Generational Stall 60 20
# Program execution time was 3.069000.
# Run # 0, 1, 3
# Generational Stall 59 19
# Program execution time was 3.000000.
# Run # 0, 1, 4
# Generational Stall 55 15
# Program execution time was 2.897000.
# Run # 0, 1, 5
# Program execution time was 3.257000.
# Run # 0, 1, 6
# Program execution time was 3.275000.
# Run # 0, 1, 7
# Fitness Convergence
# Program execution time was 2.617000.
# Run # 0, 1, 8
# Generational Stall 48 8
# Program execution time was 2.596000.
# Run # 0, 1, 9
# Generational Stall 56 16
# Program execution time was 2.901000.
# Run # 0, 1, 10
# Generational Stall 52 12
# Program execution time was 2.779000.
# Run # 0, 1, 11
# Fitness Convergence
# Program execution time was 2.414000.
# Run # 0, 1, 12
# Program execution time was 3.455000.
# Run # 0, 1, 13
# Generational Stall 58 18
# Program execution time was 3.918000.
# Run # 0, 1, 14
# Program execution time was 4.552000.
# Run # 0, 1, 15
# Generational Stall 50 10
# Program execution time was 3.555000.
# Run # 0, 1, 16
# Program execution time was 3.652000.
# Run # 0, 1, 17
# Fitness Convergence
# Program execution time was 1.662000.
# Run # 0, 1, 18
# Program execution time was 3.550000.
# Run # 0, 1, 19
# Generational Stall 57 17
# Program execution time was 3.010000.
# Run # 0, 1, 20
# Generational Stall 53 13
# Program execution time was 3.003000.
# Run # 0, 1, 21
# Generational Stall 64 24
# Program execution time was 4.271000.
# Run # 0, 1, 22
# Generational Stall 57 17
# Program execution time was 4.195000.
# Run # 0, 1, 23
# Generational Stall 51 11
# Program execution time was 3.574000.
# Run # 0, 1, 24
# Generational Stall 57 17
# Program execution time was 3.181000.
# Run # 0, 2, 0
# Generational Stall 54 14
# Program execution time was 2.877000.
# Run # 0, 2, 1
# Generational Stall 51 11
# Program execution time was 2.744000.
# Run # 0, 2, 2
# Generational Stall 50 10
# Program execution time was 2.872000.
# Run # 0, 2, 3
# Generational Stall 49 9
# Program execution time was 2.653000.
# Run # 0, 2, 4
# Generational Stall 61 21
# Program execution time was 3.167000.
# Run # 0, 2, 5
# Generational Stall 57 17
# Program execution time was 3.189000.
# Run # 0, 2, 6
# Program execution time was 3.509000.
# Run # 0, 2, 7
# Generational Stall 58 18
# Program execution time was 3.044000.
# Run # 0, 2, 8
# Program execution time was 3.307000.
# Run # 0, 2, 9
# Generational Stall 60 20
# Program execution time was 3.077000.
# Run # 0, 2, 10
# Program execution time was 3.375000.
# Run # 0, 2, 11
# Generational Stall 59 19
# Program execution time was 3.335000.
# Run # 0, 2, 12
# Program execution time was 4.336000.
# Run # 0, 2, 13
# Program execution time was 3.452000.
# Run # 0, 2, 14
# Generational Stall 51 11
# Program execution time was 2.772000.
# Run # 0, 2, 15
# Generational Stall 56 16
# Program execution time was 2.972000.
# Run # 0, 2, 16
# Generational Stall 56 16
# Program execution time was 2.950000.
# Run # 0, 2, 17
# Program execution time was 3.238000.
# Run # 0, 2, 18
# Program execution time was 3.150000.
# Run # 0, 2, 19
# Generational Stall 56 16
# Program execution time was 3.019000.
# Run # 0, 2, 20
# Program execution time was 3.301000.
# Run # 0, 2, 21
# Generational Stall 47 7
# Program execution time was 2.602000.
# Run # 0, 2, 22
# Fitness Convergence
# Program execution time was 1.079000.
# Run # 0, 2, 23
# Program execution time was 3.465000.
# Run # 0, 2, 24
# Generational Stall 58 18
# Program execution time was 3.610000.
# Run # 0, 3, 0
# Generational Stall 64 24
# Program execution time was 3.293000.
# Run # 0, 3, 1
# Generational Stall 61 21
# Program execution time was 3.258000.
# Run # 0, 3, 2
# Generational Stall 58 18
# Program execution time was 3.156000.
# Run # 0, 3, 3
# Generational Stall 57 17
# Program execution time was 3.365000.
# Run # 0, 3, 4
# Generational Stall 58 18
# Program execution time was 3.129000.
# Run # 0, 3, 5
# Generational Stall 62 22
# Program execution time was 3.154000.
# Run # 0, 3, 6
# Fitness Convergence
# Program execution time was 0.955000.
# Run # 0, 3, 7
# Generational Stall 55 15
# Program execution time was 2.891000.
# Run # 0, 3, 8
# Generational Stall 61 21
# Program execution time was 3.215000.
# Run # 0, 3, 9
# Fitness Convergence
# Program execution time was 1.431000.
# Run # 0, 3, 10
# Generational Stall 54 14
# Program execution time was 2.877000.
# Run # 0, 3, 11
# Generational Stall 49 9
# Program execution time was 2.664000.
# Run # 0, 3, 12
# Program execution time was 3.440000.
# Run # 0, 3, 13
# Program execution time was 3.430000.
# Run # 0, 3, 14
# Generational Stall 47 7
# Program execution time was 2.657000.
# Run # 0, 3, 15
# Program execution time was 3.254000.
# Run # 0, 3, 16
# Fitness Convergence
# Program execution time was 1.243000.
# Run # 0, 3, 17
# Program execution time was 3.319000.
# Run # 0, 3, 18
# Generational Stall 49 9
# Program execution time was 2.686000.
# Run # 0, 3, 19
# Program execution time was 3.283000.
# Run # 0, 3, 20
# Generational Stall 53 13
# Program execution time was 2.920000.
# Run # 0, 3, 21
# Fitness Convergence
# Program execution time was 2.488000.
# Run # 0, 3, 22
# Program execution time was 3.414000.
# Run # 0, 3, 23
# Generational Stall 51 11
# Program execution time was 2.752000.
# Run # 0, 3, 24
# Program execution time was 3.583000.
# Run # 0, 4, 0
# Generational Stall 57 17
# Program execution time was 3.558000.
# Run # 0, 4, 1
# Generational Stall 60 20
# Program execution time was 3.742000.
# Run # 0, 4, 2
# Generational Stall 60 20
# Program execution time was 3.635000.
# Run # 0, 4, 3
# Generational Stall 52 12
# Program execution time was 3.238000.
# Run # 0, 4, 4
# Generational Stall 50 10
# Program execution time was 3.242000.
# Run # 0, 4, 5
# Generational Stall 48 8
# Program execution time was 3.138000.
# Run # 0, 4, 6
# Program execution time was 4.039000.
# Run # 0, 4, 7
# Fitness Convergence
# Program execution time was 1.504000.
# Run # 0, 4, 8
# Generational Stall 49 9
# Program execution time was 3.404000.
# Run # 0, 4, 9
# Program execution time was 4.092000.
# Run # 0, 4, 10
# Generational Stall 60 20
# Program execution time was 3.832000.
# Run # 0, 4, 11
# Fitness Convergence
# Program execution time was 3.994000.
# Run # 0, 4, 12
# Generational Stall 55 15
# Program execution time was 3.554000.
# Run # 0, 4, 13
# Generational Stall 54 14
# Program execution time was 3.927000.
# Run # 0, 4, 14
# Program execution time was 4.168000.
# Run # 0, 4, 15
# Fitness Convergence
# Program execution time was 3.147000.
# Run # 0, 4, 16
# Program execution time was 3.982000.
# Run # 0, 4, 17
# Program execution time was 4.196000.
# Run # 0, 4, 18
# Program execution time was 4.102000.
# Run # 0, 4, 19
# Generational Stall 56 16
# Program execution time was 3.890000.
# Run # 0, 4, 20
# Program execution time was 4.098000.
# Run # 0, 4, 21
# Program execution time was 4.237000.
# Run # 0, 4, 22
# Generational Stall 59 19
# Program execution time was 3.857000.
# Run # 0, 4, 23
# Generational Stall 50 10
# Program execution time was 3.278000.
# Run # 0, 4, 24
# Generational Stall 50 10
# Program execution time was 3.387000.
# Run # 1, 0, 0
# Program execution time was 6.664000.
# Run # 1, 0, 1
# Program execution time was 5.504000.
# Run # 1, 0, 2
# Program execution time was 5.806000.
# Run # 1, 0, 3
# Generational Stall 65 25
# Program execution time was 5.506000.
# Run # 1, 0, 4
# Generational Stall 61 21
# Program execution time was 5.204000.
# Run # 1, 0, 5
# Program execution time was 5.366000.
# Run # 1, 0, 6
# Program execution time was 5.465000.
# Run # 1, 0, 7
# Program execution time was 5.455000.
# Run # 1, 0, 8
# Generational Stall 59 19
# Program execution time was 5.068000.
# Run # 1, 0, 9
# Program execution time was 5.490000.
# Run # 1, 0, 10
# Program execution time was 5.429000.
# Run # 1, 0, 11
# Program execution time was 5.434000.
# Run # 1, 0, 12
# Program execution time was 5.501000.
# Run # 1, 0, 13
# Program execution time was 5.430000.
# Run # 1, 0, 14
# Program execution time was 5.488000.
# Run # 1, 0, 15
# Program execution time was 5.436000.
# Run # 1, 0, 16
# Program execution time was 5.481000.
# Run # 1, 0, 17
# Generational Stall 50 10
# Program execution time was 4.558000.
# Run # 1, 0, 18
# Generational Stall 58 18
# Program execution time was 5.131000.
# Run # 1, 0, 19
# Program execution time was 5.470000.
# Run # 1, 0, 20
# Program execution time was 5.505000.
# Run # 1, 0, 21
# Program execution time was 5.449000.
# Run # 1, 0, 22
# Program execution time was 5.434000.
# Run # 1, 0, 23
# Program execution time was 5.501000.
# Run # 1, 0, 24
# Fitness Convergence
# Program execution time was 4.071000.
# Run # 1, 1, 0
# Program execution time was 5.552000.
# Run # 1, 1, 1
# Program execution time was 5.674000.
# Run # 1, 1, 2
# Program execution time was 5.478000.
# Run # 1, 1, 3
# Generational Stall 54 14
# Program execution time was 4.753000.
# Run # 1, 1, 4
# Generational Stall 58 18
# Program execution time was 5.245000.
# Run # 1, 1, 5
# Generational Stall 59 19
# Program execution time was 5.079000.
# Run # 1, 1, 6
# Generational Stall 58 18
# Program execution time was 4.960000.
# Run # 1, 1, 7
# Program execution time was 5.437000.
# Run # 1, 1, 8
# Generational Stall 55 15
# Program execution time was 4.849000.
# Run # 1, 1, 9
# Generational Stall 55 15
# Program execution time was 4.811000.
# Run # 1, 1, 10
# Program execution time was 5.506000.
# Run # 1, 1, 11
# Fitness Convergence
# Program execution time was 2.328000.
# Run # 1, 1, 12
# Generational Stall 57 17
# Program execution time was 4.960000.
# Run # 1, 1, 13
# Generational Stall 65 25
# Program execution time was 5.385000.
# Run # 1, 1, 14
# Program execution time was 5.346000.
# Run # 1, 1, 15
# Program execution time was 5.417000.
# Run # 1, 1, 16
# Generational Stall 65 25
# Program execution time was 5.443000.
# Run # 1, 1, 17
# Program execution time was 5.410000.
# Run # 1, 1, 18
# Program execution time was 5.407000.
# Run # 1, 1, 19
# Generational Stall 54 14
# Program execution time was 4.804000.
# Run # 1, 1, 20
# Generational Stall 62 22
# Program execution time was 5.708000.
# Run # 1, 1, 21
# Program execution time was 5.523000.
# Run # 1, 1, 22
# Generational Stall 54 14
# Program execution time was 4.781000.
# Run # 1, 1, 23
# Program execution time was 5.543000.
# Run # 1, 1, 24
# Program execution time was 5.380000.
# Run # 1, 2, 0
# Program execution time was 5.467000.
# Run # 1, 2, 1
# Program execution time was 5.615000.
# Run # 1, 2, 2
# Program execution time was 5.443000.
# Run # 1, 2, 3
# Program execution time was 5.532000.
# Run # 1, 2, 4
# Generational Stall 55 15
# Program execution time was 5.064000.
# Run # 1, 2, 5
# Generational Stall 65 25
# Program execution time was 5.496000.
# Run # 1, 2, 6
# Fitness Convergence
# Program execution time was 3.552000.
# Run # 1, 2, 7
# Program execution time was 5.530000.
# Run # 1, 2, 8
# Generational Stall 55 15
# Program execution time was 4.811000.
# Run # 1, 2, 9
# Program execution time was 5.502000.
# Run # 1, 2, 10
# Program execution time was 5.713000.
# Run # 1, 2, 11
# Program execution time was 5.484000.
# Run # 1, 2, 12
# Fitness Convergence
# Program execution time was 2.494000.
# Run # 1, 2, 13
# Generational Stall 62 22
# Program execution time was 5.325000.
# Run # 1, 2, 14
# Program execution time was 5.399000.
# Run # 1, 2, 15
# Program execution time was 5.755000.
# Run # 1, 2, 16
# Program execution time was 5.529000.
# Run # 1, 2, 17
# Program execution time was 5.627000.
# Run # 1, 2, 18
# Generational Stall 58 18
# Program execution time was 5.135000.
# Run # 1, 2, 19
# Program execution time was 5.447000.
# Run # 1, 2, 20
# Program execution time was 5.907000.
# Run # 1, 2, 21
# Generational Stall 56 16
# Program execution time was 5.292000.
# Run # 1, 2, 22
# Program execution time was 5.464000.
# Run # 1, 2, 23
# Generational Stall 52 12
# Program execution time was 4.631000.
# Run # 1, 2, 24
# Program execution time was 5.426000.
# Run # 1, 3, 0
# Generational Stall 51 11
# Program execution time was 4.809000.
# Run # 1, 3, 1
# Generational Stall 63 23
# Program execution time was 5.424000.
# Run # 1, 3, 2
# Program execution time was 5.662000.
# Run # 1, 3, 3
# Program execution time was 5.649000.
# Run # 1, 3, 4
# Generational Stall 64 24
# Program execution time was 5.346000.
# Run # 1, 3, 5
# Program execution time was 5.423000.
# Run # 1, 3, 6
# Generational Stall 58 18
# Program execution time was 5.110000.
# Run # 1, 3, 7
# Generational Stall 63 23
# Program execution time was 5.165000.
# Run # 1, 3, 8
# Program execution time was 5.422000.
# Run # 1, 3, 9
# Generational Stall 63 23
# Program execution time was 5.361000.
# Run # 1, 3, 10
# Generational Stall 58 18
# Program execution time was 5.118000.
# Run # 1, 3, 11
# Program execution time was 5.617000.
# Run # 1, 3, 12
# Generational Stall 64 24
# Program execution time was 5.634000.
# Run # 1, 3, 13
# Program execution time was 6.645000.
# Run # 1, 3, 14
# Generational Stall 54 14
# Program execution time was 5.586000.
# Run # 1, 3, 15
# Program execution time was 6.369000.
# Run # 1, 3, 16
# Generational Stall 63 23
# Program execution time was 6.121000.
# Run # 1, 3, 17
# Fitness Convergence
# Program execution time was 2.745000.
# Run # 1, 3, 18
# Program execution time was 7.241000.
# Run # 1, 3, 19
# Program execution time was 6.711000.
# Run # 1, 3, 20
# Program execution time was 6.423000.
# Run # 1, 3, 21
# Program execution time was 6.383000.
# Run # 1, 3, 22
# Program execution time was 6.223000.
# Run # 1, 3, 23
# Generational Stall 57 17
# Program execution time was 5.842000.
# Run # 1, 3, 24
# Generational Stall 52 12
# Program execution time was 5.289000.
# Run # 1, 4, 0
# Generational Stall 64 24
# Program execution time was 6.307000.
# Run # 1, 4, 1
# Generational Stall 59 19
# Program execution time was 5.014000.
# Run # 1, 4, 2
# Program execution time was 5.407000.
# Run # 1, 4, 3
# Generational Stall 52 12
# Program execution time was 4.711000.
# Run # 1, 4, 4
# Program execution time was 5.443000.
# Run # 1, 4, 5
# Generational Stall 58 18
# Program execution time was 4.946000.
# Run # 1, 4, 6
# Program execution time was 5.436000.
# Run # 1, 4, 7
# Program execution time was 6.435000.
# Run # 1, 4, 8
# Generational Stall 65 25
# Program execution time was 5.900000.
# Run # 1, 4, 9
# Program execution time was 5.722000.
# Run # 1, 4, 10
# Program execution time was 5.697000.
# Run # 1, 4, 11
# Generational Stall 58 18
# Program execution time was 5.128000.
# Run # 1, 4, 12
# Program execution time was 5.421000.
# Run # 1, 4, 13
# Program execution time was 5.360000.
# Run # 1, 4, 14
# Program execution time was 5.774000.
# Run # 1, 4, 15
# Program execution time was 5.578000.
# Run # 1, 4, 16
# Program execution time was 6.192000.
# Run # 1, 4, 17
# Generational Stall 60 20
# Program execution time was 6.024000.
# Run # 1, 4, 18
# Program execution time was 6.491000.
# Run # 1, 4, 19
# Program execution time was 6.481000.
# Run # 1, 4, 20
# Program execution time was 6.424000.
# Run # 1, 4, 21
# Program execution time was 6.867000.
# Run # 1, 4, 22
# Program execution time was 6.813000.
# Run # 1, 4, 23
# Program execution time was 6.557000.
# Run # 1, 4, 24
# Fitness Convergence
# Program execution time was 5.339000.
# Run # 2, 0, 0
# Program execution time was 11.373000.
# Run # 2, 0, 1
# Program execution time was 11.086000.
# Run # 2, 0, 2
# Generational Stall 62 22
# Program execution time was 11.986000.
# Run # 2, 0, 3
# Program execution time was 11.353000.
# Run # 2, 0, 4
# Program execution time was 11.794000.
# Run # 2, 0, 5
# Generational Stall 56 16
# Program execution time was 10.146000.
# Run # 2, 0, 6
# Generational Stall 59 19
# Program execution time was 10.576000.
# Run # 2, 0, 7
# Generational Stall 55 15
# Program execution time was 10.126000.
# Run # 2, 0, 8
# Program execution time was 12.074000.
# Run # 2, 0, 9
# Program execution time was 11.364000.
# Run # 2, 0, 10
# Program execution time was 11.367000.
# Run # 2, 0, 11
# Program execution time was 11.038000.
# Run # 2, 0, 12
# Program execution time was 11.178000.
# Run # 2, 0, 13
# Program execution time was 11.335000.
# Run # 2, 0, 14
# Program execution time was 11.491000.
# Run # 2, 0, 15
# Program execution time was 11.249000.
# Run # 2, 0, 16
# Program execution time was 11.138000.
# Run # 2, 0, 17
# Program execution time was 11.376000.
# Run # 2, 0, 18
# Program execution time was 11.292000.
# Run # 2, 0, 19
# Generational Stall 60 20
# Program execution time was 10.367000.
# Run # 2, 0, 20
# Program execution time was 11.048000.
# Run # 2, 0, 21
# Program execution time was 11.386000.
# Run # 2, 0, 22
# Program execution time was 11.474000.
# Run # 2, 0, 23
# Program execution time was 11.243000.
# Run # 2, 0, 24
# Program execution time was 11.226000.
# Run # 2, 1, 0
# Program execution time was 11.871000.
# Run # 2, 1, 1
# Generational Stall 57 17
# Program execution time was 10.806000.
# Run # 2, 1, 2
# Program execution time was 13.586000.
# Run # 2, 1, 3
# Generational Stall 48 8
# Program execution time was 9.017000.
# Run # 2, 1, 4
# Program execution time was 11.536000.
# Run # 2, 1, 5
# Program execution time was 11.433000.
# Run # 2, 1, 6
# Program execution time was 11.358000.
# Run # 2, 1, 7
# Generational Stall 56 16
# Program execution time was 10.162000.
# Run # 2, 1, 8
# Program execution time was 11.301000.
# Run # 2, 1, 9
# Program execution time was 11.237000.
# Run # 2, 1, 10
# Program execution time was 11.415000.
# Run # 2, 1, 11
# Program execution time was 11.340000.
# Run # 2, 1, 12
# Program execution time was 11.188000.
# Run # 2, 1, 13
# Program execution time was 11.776000.
# Run # 2, 1, 14
# Generational Stall 59 19
# Program execution time was 10.350000.
# Run # 2, 1, 15
# Program execution time was 11.910000.
# Run # 2, 1, 16
# Generational Stall 62 22
# Program execution time was 14.819000.
# Run # 2, 1, 17
# Program execution time was 14.541000.
# Run # 2, 1, 18
# Program execution time was 13.902000.
# Run # 2, 1, 19
# Generational Stall 54 14
# Program execution time was 11.224000.
# Run # 2, 1, 20
# Program execution time was 11.603000.
# Run # 2, 1, 21
# Generational Stall 61 21
# Program execution time was 11.271000.
# Run # 2, 1, 22
# Program execution time was 11.286000.
# Run # 2, 1, 23
# Program execution time was 11.780000.
# Run # 2, 1, 24
# Program execution time was 11.182000.
# Run # 2, 2, 0
# Program execution time was 11.109000.
# Run # 2, 2, 1
# Program execution time was 11.617000.
# Run # 2, 2, 2
# Program execution time was 11.224000.
# Run # 2, 2, 3
# Program execution time was 11.571000.
# Run # 2, 2, 4
# Program execution time was 11.570000.
# Run # 2, 2, 5
# Program execution time was 11.380000.
# Run # 2, 2, 6
# Generational Stall 58 18
# Program execution time was 10.656000.
# Run # 2, 2, 7
# Program execution time was 11.902000.
# Run # 2, 2, 8
# Program execution time was 11.818000.
# Run # 2, 2, 9
# Generational Stall 60 20
# Program execution time was 12.970000.
# Run # 2, 2, 10
# Fitness Convergence
# Program execution time was 6.709000.
# Run # 2, 2, 11
# Generational Stall 64 24
# Program execution time was 13.379000.
# Run # 2, 2, 12
# Program execution time was 13.472000.
# Run # 2, 2, 13
# Program execution time was 11.210000.
# Run # 2, 2, 14
# Program execution time was 11.278000.
# Run # 2, 2, 15
# Program execution time was 11.110000.
# Run # 2, 2, 16
# Program execution time was 11.456000.
# Run # 2, 2, 17
# Program execution time was 11.275000.
# Run # 2, 2, 18
# Program execution time was 11.035000.
# Run # 2, 2, 19
# Generational Stall 60 20
# Program execution time was 10.362000.
# Run # 2, 2, 20
# Program execution time was 11.175000.
# Run # 2, 2, 21
# Generational Stall 54 14
# Program execution time was 9.851000.
# Run # 2, 2, 22
# Generational Stall 59 19
# Program execution time was 10.766000.
# Run # 2, 2, 23
# Generational Stall 52 12
# Program execution time was 9.552000.
# Run # 2, 2, 24
# Program execution time was 11.315000.
# Run # 2, 3, 0
# Program execution time was 14.248000.
# Run # 2, 3, 1
# Generational Stall 63 23
# Program execution time was 12.540000.
# Run # 2, 3, 2
# Program execution time was 12.040000.
# Run # 2, 3, 3
# Generational Stall 64 24
# Program execution time was 12.974000.
# Run # 2, 3, 4
# Program execution time was 16.757000.
# Run # 2, 3, 5
# Generational Stall 62 22
# Program execution time was 15.126000.
# Run # 2, 3, 6
# Program execution time was 15.485000.
# Run # 2, 3, 7
# Program execution time was 12.963000.
# Run # 2, 3, 8
# Program execution time was 11.332000.
# Run # 2, 3, 9
# Program execution time was 11.522000.
# Run # 2, 3, 10
# Program execution time was 12.472000.
# Run # 2, 3, 11
# Program execution time was 16.800000.
# Run # 2, 3, 12
# Program execution time was 14.650000.
# Run # 2, 3, 13
# Generational Stall 56 16
# Program execution time was 13.551000.
# Run # 2, 3, 14
# Program execution time was 13.653000.
# Run # 2, 3, 15
# Program execution time was 13.121000.
# Run # 2, 3, 16
# Program execution time was 12.127000.
# Run # 2, 3, 17
# Program execution time was 11.634000.
# Run # 2, 3, 18
# Program execution time was 13.715000.
# Run # 2, 3, 19
# Generational Stall 56 16
# Program execution time was 16.812000.
# Run # 2, 3, 20
# Program execution time was 13.528000.
# Run # 2, 3, 21
# Program execution time was 11.173000.
# Run # 2, 3, 22
# Generational Stall 58 18
# Program execution time was 10.472000.
# Run # 2, 3, 23
# Program execution time was 13.971000.
# Run # 2, 3, 24
# Program execution time was 12.892000.
# Run # 2, 4, 0
# Generational Stall 54 14
# Program execution time was 9.749000.
# Run # 2, 4, 1
# Program execution time was 11.151000.
# Run # 2, 4, 2
# Program execution time was 11.130000.
# Run # 2, 4, 3
# Generational Stall 65 25
# Program execution time was 11.444000.
# Run # 2, 4, 4
# Program execution time was 11.764000.
# Run # 2, 4, 5
# Program execution time was 14.365000.
# Run # 2, 4, 6
# Program execution time was 14.706000.
# Run # 2, 4, 7
# Generational Stall 53 13
# Program execution time was 10.776000.
# Run # 2, 4, 8
# Program execution time was 11.637000.
# Run # 2, 4, 9
# Program execution time was 11.256000.
# Run # 2, 4, 10
# Program execution time was 11.303000.
# Run # 2, 4, 11
# Program execution time was 11.503000.
# Run # 2, 4, 12
# Program execution time was 11.534000.
# Run # 2, 4, 13
# Program execution time was 11.094000.
# Run # 2, 4, 14
# Program execution time was 11.142000.
# Run # 2, 4, 15
# Program execution time was 11.684000.
# Run # 2, 4, 16
# Program execution time was 11.734000.
# Run # 2, 4, 17
# Program execution time was 11.519000.
# Run # 2, 4, 18
# Program execution time was 11.289000.
# Run # 2, 4, 19
# Program execution time was 11.493000.
# Run # 2, 4, 20
# Program execution time was 11.816000.
# Run # 2, 4, 21
# Generational Stall 61 21
# Program execution time was 10.594000.
# Run # 2, 4, 22
# Program execution time was 11.192000.
# Run # 2, 4, 23
# Program execution time was 11.337000.
# Run # 2, 4, 24
# Program execution time was 11.310000.
# Run # 3, 0, 0
# Generational Stall 62 22
# Program execution time was 14.918000.
# Run # 3, 0, 1
# Program execution time was 15.586000.
# Run # 3, 0, 2
# Generational Stall 63 23
# Program execution time was 15.917000.
# Run # 3, 0, 3
# Program execution time was 15.610000.
# Run # 3, 0, 4
# Generational Stall 60 20
# Program execution time was 15.339000.
# Run # 3, 0, 5
# Program execution time was 18.557000.
# Run # 3, 0, 6
# Program execution time was 18.726000.
# Run # 3, 0, 7
# Program execution time was 15.233000.
# Run # 3, 0, 8
# Program execution time was 15.657000.
# Run # 3, 0, 9
# Program execution time was 16.532000.
# Run # 3, 0, 10
# Program execution time was 16.208000.
# Run # 3, 0, 11
# Program execution time was 15.784000.
# Run # 3, 0, 12
# Program execution time was 15.743000.
# Run # 3, 0, 13
# Program execution time was 15.430000.
# Run # 3, 0, 14
# Program execution time was 15.618000.
# Run # 3, 0, 15
# Generational Stall 56 16
# Program execution time was 14.172000.
# Run # 3, 0, 16
# Program execution time was 20.023000.
# Run # 3, 0, 17
# Program execution time was 20.265000.
# Run # 3, 0, 18
# Program execution time was 17.549000.
# Run # 3, 0, 19
# Program execution time was 15.693000.
# Run # 3, 0, 20
# Program execution time was 16.121000.
# Run # 3, 0, 21
# Program execution time was 17.402000.
# Run # 3, 0, 22
# Program execution time was 20.524000.
# Run # 3, 0, 23
# Program execution time was 17.215000.
# Run # 3, 0, 24
# Program execution time was 16.220000.
# Run # 3, 1, 0
# Program execution time was 18.433000.
# Run # 3, 1, 1
# Program execution time was 20.613000.
# Run # 3, 1, 2
# Program execution time was 18.754000.
# Run # 3, 1, 3
# Program execution time was 15.682000.
# Run # 3, 1, 4
# Program execution time was 16.412000.
# Run # 3, 1, 5
# Program execution time was 16.388000.
# Run # 3, 1, 6
# Program execution time was 15.241000.
# Run # 3, 1, 7
# Program execution time was 15.166000.
# Run # 3, 1, 8
# Program execution time was 15.171000.
# Run # 3, 1, 9
# Program execution time was 15.497000.
# Run # 3, 1, 10
# Program execution time was 15.632000.
# Run # 3, 1, 11
# Program execution time was 15.377000.
# Run # 3, 1, 12
# Program execution time was 15.988000.
# Run # 3, 1, 13
# Program execution time was 17.190000.
# Run # 3, 1, 14
# Program execution time was 19.167000.
# Run # 3, 1, 15
# Program execution time was 18.841000.
# Run # 3, 1, 16
# Generational Stall 58 18
# Program execution time was 17.118000.
# Run # 3, 1, 17
# Program execution time was 18.666000.
# Run # 3, 1, 18
# Program execution time was 17.340000.
# Run # 3, 1, 19
# Program execution time was 16.074000.
# Run # 3, 1, 20
# Program execution time was 15.785000.
# Run # 3, 1, 21
# Program execution time was 19.369000.
# Run # 3, 1, 22
# Generational Stall 60 20
# Program execution time was 17.811000.
# Run # 3, 1, 23
# Program execution time was 17.234000.
# Run # 3, 1, 24
# Generational Stall 60 20
# Program execution time was 14.587000.
# Run # 3, 2, 0
# Program execution time was 15.366000.
# Run # 3, 2, 1
# Program execution time was 16.354000.
# Run # 3, 2, 2
# Program execution time was 16.219000.
# Run # 3, 2, 3
# Generational Stall 65 25
# Program execution time was 15.960000.
# Run # 3, 2, 4
# Program execution time was 15.315000.
# Run # 3, 2, 5
# Program execution time was 15.492000.
# Run # 3, 2, 6
# Program execution time was 15.626000.
# Run # 3, 2, 7
# Program execution time was 20.168000.
# Run # 3, 2, 8
# Program execution time was 19.284000.
# Run # 3, 2, 9
# Program execution time was 19.451000.
# Run # 3, 2, 10
# Program execution time was 16.935000.
# Run # 3, 2, 11
# Program execution time was 15.825000.
# Run # 3, 2, 12
# Program execution time was 15.753000.
# Run # 3, 2, 13
# Program execution time was 16.242000.
# Run # 3, 2, 14
# Generational Stall 62 22
# Program execution time was 15.506000.
# Run # 3, 2, 15
# Program execution time was 15.946000.
# Run # 3, 2, 16
# Generational Stall 62 22
# Program execution time was 15.839000.
# Run # 3, 2, 17
# Program execution time was 16.290000.
# Run # 3, 2, 18
# Program execution time was 15.582000.
# Run # 3, 2, 19
# Program execution time was 17.199000.
# Run # 3, 2, 20
# Program execution time was 15.541000.
# Run # 3, 2, 21
# Program execution time was 15.361000.
# Run # 3, 2, 22
# Program execution time was 15.694000.
# Run # 3, 2, 23
# Program execution time was 15.925000.
# Run # 3, 2, 24
# Program execution time was 16.568000.
# Run # 3, 3, 0
# Program execution time was 15.503000.
# Run # 3, 3, 1
# Program execution time was 15.872000.
# Run # 3, 3, 2
# Program execution time was 16.547000.
# Run # 3, 3, 3
# Program execution time was 15.527000.
# Run # 3, 3, 4
# Program execution time was 15.644000.
# Run # 3, 3, 5
# Program execution time was 16.388000.
# Run # 3, 3, 6
# Program execution time was 15.685000.
# Run # 3, 3, 7
# Generational Stall 63 23
# Program execution time was 15.284000.
# Run # 3, 3, 8
# Program execution time was 15.530000.
# Run # 3, 3, 9
# Program execution time was 15.311000.
# Run # 3, 3, 10
# Program execution time was 15.914000.
# Run # 3, 3, 11
# Generational Stall 58 18
# Program execution time was 14.754000.
# Run # 3, 3, 12
# Program execution time was 15.567000.
# Run # 3, 3, 13
# Program execution time was 15.334000.
# Run # 3, 3, 14
# Generational Stall 65 25
# Program execution time was 16.106000.
# Run # 3, 3, 15
# Program execution time was 16.364000.
# Run # 3, 3, 16
# Program execution time was 15.566000.
# Run # 3, 3, 17
# Program execution time was 15.413000.
# Run # 3, 3, 18
# Program execution time was 15.464000.
# Run # 3, 3, 19
# Program execution time was 15.463000.
# Run # 3, 3, 20
# Program execution time was 16.500000.
# Run # 3, 3, 21
# Generational Stall 63 23
# Program execution time was 15.175000.
# Run # 3, 3, 22
# Program execution time was 15.882000.
# Run # 3, 3, 23
# Program execution time was 16.108000.
# Run # 3, 3, 24
# Program execution time was 15.499000.
# Run # 3, 4, 0
# Program execution time was 15.553000.
# Run # 3, 4, 1
# Program execution time was 15.965000.
# Run # 3, 4, 2
# Program execution time was 15.532000.
# Run # 3, 4, 3
# Fitness Convergence
# Program execution time was 9.436000.
# Run # 3, 4, 4
# Program execution time was 15.340000.
# Run # 3, 4, 5
# Program execution time was 15.972000.
# Run # 3, 4, 6
# Program execution time was 15.717000.
# Run # 3, 4, 7
# Program execution time was 15.921000.
# Run # 3, 4, 8
# Program execution time was 15.552000.
# Run # 3, 4, 9
# Program execution time was 16.282000.
# Run # 3, 4, 10
# Program execution time was 16.134000.
# Run # 3, 4, 11
# Program execution time was 15.853000.
# Run # 3, 4, 12
# Program execution time was 16.021000.
# Run # 3, 4, 13
# Program execution time was 15.748000.
# Run # 3, 4, 14
# Program execution time was 15.498000.
# Run # 3, 4, 15
# Program execution time was 15.495000.
# Run # 3, 4, 16
# Program execution time was 15.469000.
# Run # 3, 4, 17
# Program execution time was 15.215000.
# Run # 3, 4, 18
# Program execution time was 15.343000.
# Run # 3, 4, 19
# Program execution time was 15.612000.
# Run # 3, 4, 20
# Program execution time was 16.476000.
# Run # 3, 4, 21
# Program execution time was 15.733000.
# Run # 3, 4, 22
# Program execution time was 16.784000.
# Run # 3, 4, 23
# Program execution time was 15.799000.
# Run # 3, 4, 24
# Program execution time was 16.117000.
# Run # 4, 0, 0
# Program execution time was 21.686000.
# Run # 4, 0, 1
# Generational Stall 65 25
# Program execution time was 22.390000.
# Run # 4, 0, 2
# Program execution time was 22.256000.
# Run # 4, 0, 3
# Program execution time was 21.798000.
# Run # 4, 0, 4
# Program execution time was 22.663000.
# Run # 4, 0, 5
# Program execution time was 21.851000.
# Run # 4, 0, 6
# Program execution time was 21.242000.
# Run # 4, 0, 7
# Program execution time was 21.387000.
# Run # 4, 0, 8
# Generational Stall 59 19
# Program execution time was 19.977000.
# Run # 4, 0, 9
# Generational Stall 63 23
# Program execution time was 22.570000.
# Run # 4, 0, 10
# Program execution time was 22.244000.
# Run # 4, 0, 11
# Program execution time was 22.120000.
# Run # 4, 0, 12
# Program execution time was 22.565000.
# Run # 4, 0, 13
# Generational Stall 57 17
# Program execution time was 21.641000.
# Run # 4, 0, 14
# Program execution time was 22.252000.
# Run # 4, 0, 15
# Program execution time was 25.362000.
# Run # 4, 0, 16
# Program execution time was 26.501000.
# Run # 4, 0, 17
# Program execution time was 22.764000.
# Run # 4, 0, 18
# Generational Stall 64 24
# Program execution time was 21.742000.
# Run # 4, 0, 19
# Program execution time was 23.054000.
# Run # 4, 0, 20
# Program execution time was 21.870000.
# Run # 4, 0, 21
# Program execution time was 22.156000.
# Run # 4, 0, 22
# Program execution time was 22.905000.
# Run # 4, 0, 23
# Program execution time was 21.972000.
# Run # 4, 0, 24
# Program execution time was 22.676000.
# Run # 4, 1, 0
# Program execution time was 23.475000.
# Run # 4, 1, 1
# Program execution time was 22.043000.
# Run # 4, 1, 2
# Program execution time was 21.965000.
# Run # 4, 1, 3
# Program execution time was 21.775000.
# Run # 4, 1, 4
# Program execution time was 21.808000.
# Run # 4, 1, 5
# Program execution time was 22.312000.
# Run # 4, 1, 6
# Program execution time was 21.900000.
# Run # 4, 1, 7
# Program execution time was 21.946000.
# Run # 4, 1, 8
# Program execution time was 21.848000.
# Run # 4, 1, 9
# Program execution time was 21.739000.
# Run # 4, 1, 10
# Program execution time was 21.817000.
# Run # 4, 1, 11
# Program execution time was 21.854000.
# Run # 4, 1, 12
# Program execution time was 23.137000.
# Run # 4, 1, 13
# Program execution time was 22.897000.
# Run # 4, 1, 14
# Program execution time was 22.917000.
# Run # 4, 1, 15
# Program execution time was 22.453000.
# Run # 4, 1, 16
# Program execution time was 22.365000.
# Run # 4, 1, 17
# Program execution time was 22.829000.
# Run # 4, 1, 18
# Program execution time was 22.635000.
# Run # 4, 1, 19
# Program execution time was 22.094000.
# Run # 4, 1, 20
# Generational Stall 63 23
# Program execution time was 21.637000.
# Run # 4, 1, 21
# Program execution time was 23.237000.
# Run # 4, 1, 22
# Program execution time was 23.571000.
# Run # 4, 1, 23
# Program execution time was 22.796000.
# Run # 4, 1, 24
# Program execution time was 22.125000.
# Run # 4, 2, 0
# Program execution time was 21.858000.
# Run # 4, 2, 1
# Program execution time was 22.151000.
# Run # 4, 2, 2
# Program execution time was 21.727000.
# Run # 4, 2, 3
# Program execution time was 21.920000.
# Run # 4, 2, 4
# Program execution time was 22.054000.
# Run # 4, 2, 5
# Program execution time was 21.952000.
# Run # 4, 2, 6
# Program execution time was 21.820000.
# Run # 4, 2, 7
# Program execution time was 21.923000.
# Run # 4, 2, 8
# Program execution time was 21.940000.
# Run # 4, 2, 9
# Program execution time was 21.927000.
# Run # 4, 2, 10
# Program execution time was 21.830000.
# Run # 4, 2, 11
# Program execution time was 22.014000.
# Run # 4, 2, 12
# Program execution time was 21.870000.
# Run # 4, 2, 13
# Program execution time was 21.777000.
# Run # 4, 2, 14
# Program execution time was 21.972000.
# Run # 4, 2, 15
# Program execution time was 22.081000.
# Run # 4, 2, 16
# Program execution time was 22.201000.
# Run # 4, 2, 17
# Program execution time was 21.731000.
# Run # 4, 2, 18
# Program execution time was 22.003000.
# Run # 4, 2, 19
# Program execution time was 22.059000.
# Run # 4, 2, 20
# Program execution time was 21.924000.
# Run # 4, 2, 21
# Program execution time was 22.117000.
# Run # 4, 2, 22
# Program execution time was 22.011000.
# Run # 4, 2, 23
# Program execution time was 22.692000.
# Run # 4, 2, 24
# Program execution time was 24.121000.
# Run # 4, 3, 0
# Program execution time was 23.795000.
# Run # 4, 3, 1
# Program execution time was 23.859000.
# Run # 4, 3, 2
# Program execution time was 22.937000.
# Run # 4, 3, 3
# Generational Stall 61 21
# Program execution time was 22.260000.
# Run # 4, 3, 4
# Program execution time was 25.299000.
# Run # 4, 3, 5
# Program execution time was 23.614000.
# Run # 4, 3, 6
# Program execution time was 22.373000.
# Run # 4, 3, 7
# Program execution time was 22.150000.
# Run # 4, 3, 8
# Program execution time was 22.300000.
# Run # 4, 3, 9
# Program execution time was 22.780000.
# Run # 4, 3, 10
# Program execution time was 21.997000.
# Run # 4, 3, 11
# Program execution time was 22.208000.
# Run # 4, 3, 12
# Generational Stall 57 17
# Program execution time was 19.875000.
# Run # 4, 3, 13
# Program execution time was 22.125000.
# Run # 4, 3, 14
# Program execution time was 21.913000.
# Run # 4, 3, 15
# Program execution time was 21.794000.
# Run # 4, 3, 16
# Program execution time was 22.583000.
# Run # 4, 3, 17
# Program execution time was 23.755000.
# Run # 4, 3, 18
# Program execution time was 22.260000.
# Run # 4, 3, 19
# Program execution time was 22.540000.
# Run # 4, 3, 20
# Program execution time was 22.100000.
# Run # 4, 3, 21
# Program execution time was 21.921000.
# Run # 4, 3, 22
# Program execution time was 22.060000.
# Run # 4, 3, 23
# Program execution time was 21.953000.
# Run # 4, 3, 24
# Program execution time was 23.112000.
# Run # 4, 4, 0
# Program execution time was 21.891000.
# Run # 4, 4, 1
# Program execution time was 21.953000.
# Run # 4, 4, 2
# Program execution time was 21.784000.
# Run # 4, 4, 3
# Program execution time was 22.324000.
# Run # 4, 4, 4
# Program execution time was 22.411000.
# Run # 4, 4, 5
# Program execution time was 22.022000.
# Run # 4, 4, 6
# Program execution time was 22.015000.
# Run # 4, 4, 7
# Program execution time was 22.032000.
# Run # 4, 4, 8
# Program execution time was 22.184000.
# Run # 4, 4, 9
# Fitness Convergence
# Program execution time was 16.445000.
# Run # 4, 4, 10
# Program execution time was 21.937000.
# Run # 4, 4, 11
# Program execution time was 22.161000.
# Run # 4, 4, 12
# Program execution time was 21.952000.
# Run # 4, 4, 13
# Program execution time was 22.114000.
# Run # 4, 4, 14
# Program execution time was 22.707000.
# Run # 4, 4, 15
# Program execution time was 21.923000.
# Run # 4, 4, 16
# Generational Stall 64 24
# Program execution time was 21.723000.
# Run # 4, 4, 17
# Program execution time was 21.998000.
# Run # 4, 4, 18
# Program execution time was 21.713000.
# Run # 4, 4, 19
# Program execution time was 21.925000.
# Run # 4, 4, 20
# Program execution time was 22.369000.
# Run # 4, 4, 21
# Program execution time was 22.678000.
# Run # 4, 4, 22
# Program execution time was 21.830000.
# Run # 4, 4, 23
# Program execution time was 22.141000.
# Run # 4, 4, 24
# Program execution time was 21.859000.
# array([[[  5.00000000e-01,   5.38834607e+02,   0.00000000e+00],
#         [  1.00000000e+00,   5.13267002e+02,   0.00000000e+00],
#         [  1.50000000e+00,   5.00067483e+02,   0.00000000e+00],
#         [  2.00000000e+00,   4.10411043e+02,   0.00000000e+00],
#         [  3.00000000e+00,   5.23290381e+02,   0.00000000e+00]],
#
#        [[  5.00000000e-01,   9.07168893e+02,   4.71299001e-01],
#         [  1.00000000e+00,   8.73199597e+02,   6.50182465e-01],
#         [  1.50000000e+00,   1.00320721e+03,   6.69435121e-01],
#         [  2.00000000e+00,   8.93342094e+02,   5.99589373e-01],
#         [  3.00000000e+00,   9.91157172e+02,   5.53411681e-01]],
#
#        [[  5.00000000e-01,   1.70280199e+03,   7.87497626e-03],
#         [  1.00000000e+00,   2.73250312e+03,   9.14096053e-03],
#         [  1.50000000e+00,   2.10179488e+03,   8.44186593e-03],
#         [  2.00000000e+00,   2.27450878e+03,   7.69005892e-03],
#         [  3.00000000e+00,   2.27096904e+03,   7.78970613e-03]],
#
#        [[  5.00000000e-01,   2.03058393e+03,   2.59821204e-03],
#         [  1.00000000e+00,   2.59941256e+03,   2.29877423e-03],
#         [  1.50000000e+00,   2.25715172e+03,   2.48748625e-03],
#         [  2.00000000e+00,   2.24524555e+03,   2.16471300e-03],
#         [  3.00000000e+00,   2.27242049e+03,   2.13166440e-03]],
#
#        [[  5.00000000e-01,   2.87029103e+03,   4.61523342e-02],
#         [  1.00000000e+00,   2.68691288e+03,   2.76208515e-02],
#         [  1.50000000e+00,   3.01806862e+03,   2.78879391e-02],
#         [  2.00000000e+00,   3.32869218e+03,   3.58971244e-02],
#         [  3.00000000e+00,   2.92339217e+03,   3.97898745e-02]]])
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-25ebc0c8e88f> in <module>()
#       1 import HyperOpt as run
# ----> 2 results=run.Hyper_Opt(Continuous_on=False,Discrete_on=True)
#
# C:\Users\James\Dropbox\UCB\Research\ETAs\Design\Gnowee_Dev\BenchmarkPlots\HyperOpt.py in Hyper_Opt(Continuous_on, Discrete_on)
#     173         label=['\\textbf{Eil51}','\\textbf{Pr107}','\\textbf{Ch150}']
#     174         title='\\textbf{Meta-Optimization of Gnowee Algorithm for Step Scaling Factor (S.sf)}'  #!! - Ignore
# --> 175         op.Plot_Meta_Optimization(results,label,title)
#     176
#     177     return results
#
# C:\Users\James\Dropbox\UCB\Research\ETAs\Design\Gnowee_Dev\OptiPlot.pyc in Plot_Meta_Optimization(data, label, title, debug)
#     364         y=data[i,:,1]
#     365         yerr=data[i,:,2]
# --> 366         ax.plot(x,y,marker[i],label=label[i])
#     367 #        ax.errorbar(x, y, yerr=yerr, fmt=marker[i],label=label[i])
#     368         # Add and locate legend
#
# IndexError: list index out of range

# %%
#S.p
import numpy as np
results=np.array([[[  5.00000000e+00,   7.07521247e+02,   0.00000000e+00],
        [  1.50000000e+01,   6.50005617e+02,   0.00000000e+00],
        [  2.00000000e+01,   7.88194108e+02,   0.00000000e+00],
        [  2.50000000e+01,   6.83510222e+02,   0.00000000e+00],
        [  3.00000000e+01,   6.02230029e+02,   0.00000000e+00],
        [  4.00000000e+01,   6.41022146e+02,   0.00000000e+00],
        [  6.00000000e+01,   6.05067977e+02,   0.00000000e+00],
        [  8.00000000e+01,   6.20584414e+02,   0.00000000e+00]],

       [[  5.00000000e+00,   3.48795957e+03,   3.83174777e+00],
        [  1.50000000e+01,   1.64058477e+03,   1.39584846e+00],
        [  2.00000000e+01,   1.62672723e+03,   1.20043948e+00],
        [  2.50000000e+01,   1.32146620e+03,   1.06714268e+00],
        [  3.00000000e+01,   1.32022407e+03,   8.84522159e-01],
        [  4.00000000e+01,   1.23515522e+03,   7.12256617e-01],
        [  6.00000000e+01,   1.28497288e+03,   5.64609194e-01],
        [  8.00000000e+01,   1.19499358e+03,   3.80063487e-01]],

       [[  5.00000000e+00,   9.14731915e+03,   5.45631342e-02],
        [  1.50000000e+01,   4.17102706e+03,   2.13565522e-02],
        [  2.00000000e+01,   3.51508354e+03,   1.49884445e-02],
        [  2.50000000e+01,   3.56812239e+03,   1.26493477e-02],
        [  3.00000000e+01,   3.25403396e+03,   1.15809002e-02],
        [  4.00000000e+01,   2.98684855e+03,   8.11614276e-03],
        [  6.00000000e+01,   2.89296948e+03,   7.55319538e-03],
        [  8.00000000e+01,   2.62793886e+03,   5.55490682e-03]],

       [[  5.00000000e+00,   9.13133932e+03,   1.55096912e-02],
        [  1.50000000e+01,   4.41449770e+03,   5.75119489e-03],
        [  2.00000000e+01,   3.88618747e+03,   4.64776878e-03],
        [  2.50000000e+01,   3.32747664e+03,   3.35480695e-03],
        [  3.00000000e+01,   3.70426938e+03,   3.32352552e-03],
        [  4.00000000e+01,   3.18101629e+03,   2.15226440e-03],
        [  6.00000000e+01,   3.13097636e+03,   1.99425890e-03],
        [  8.00000000e+01,   3.41742011e+03,   1.12844151e-03]],

       [[  5.00000000e+00,   9.51707879e+03,   2.81381925e-01],
        [  1.50000000e+01,   5.47258665e+03,   1.01774822e-01],
        [  2.00000000e+01,   5.19915876e+03,   8.93512070e-02],
        [  2.50000000e+01,   5.77848686e+03,   6.89872460e-02],
        [  3.00000000e+01,   4.82940058e+03,   4.44359392e-02],
        [  4.00000000e+01,   4.85927278e+03,   3.78692346e-02],
        [  6.00000000e+01,   4.33207061e+03,   3.08370360e-02],
        [  8.00000000e+01,   4.73877724e+03,   1.84268041e-02]]])

# %%
#S.fl
import numpy as np
results=np.array([[[  0.00000000e+00,   7.05862746e+02,   0.00000000e+00],
        [  1.50000000e-01,   6.48215219e+02,   0.00000000e+00],
        [  3.00000000e-01,   6.15607806e+02,   0.00000000e+00],
        [  4.50000000e-01,   6.65164564e+02,   0.00000000e+00],
        [  6.00000000e-01,   6.31203618e+02,   0.00000000e+00],
        [  7.50000000e-01,   8.21291787e+02,   0.00000000e+00],
        [  9.00000000e-01,   5.89723344e+02,   0.00000000e+00],
        [  1.00000000e+00,   6.50805011e+02,   0.00000000e+00]],

       [[  0.00000000e+00,   1.36065232e+03,   9.43211082e-01],
        [  1.50000000e-01,   1.07296997e+03,   8.05273239e-01],
        [  3.00000000e-01,   1.43820105e+03,   1.06295092e+00],
        [  4.50000000e-01,   1.13222441e+03,   7.32231895e-01],
        [  6.00000000e-01,   1.47228357e+03,   1.06416551e+00],
        [  7.50000000e-01,   1.26669239e+03,   9.13529387e-01],
        [  9.00000000e-01,   1.22176123e+03,   9.11519209e-01],
        [  1.00000000e+00,   1.21642182e+03,   8.62965659e-01]],

       [[  0.00000000e+00,   3.26418045e+03,   1.29635576e-02],
        [  1.50000000e-01,   3.49165786e+03,   1.11207428e-02],
        [  3.00000000e-01,   3.44270220e+03,   1.64702485e-02],
        [  4.50000000e-01,   3.91160572e+03,   1.01936862e-02],
        [  6.00000000e-01,   3.87867299e+03,   1.57442292e-02],
        [  7.50000000e-01,   4.21617846e+03,   1.26042772e-02],
        [  9.00000000e-01,   2.99727938e+03,   1.26634239e-02],
        [  1.00000000e+00,   4.27508557e+03,   1.16093484e-02]],

       [[  0.00000000e+00,   3.51093391e+03,   3.04969260e-03],
        [  1.50000000e-01,   3.35822613e+03,   3.24895321e-03],
        [  3.00000000e-01,   3.56324990e+03,   4.23583419e-03],
        [  4.50000000e-01,   3.79872953e+03,   3.55873783e-03],
        [  6.00000000e-01,   3.53442157e+03,   4.11352760e-03],
        [  7.50000000e-01,   3.66114488e+03,   3.36321313e-03],
        [  9.00000000e-01,   3.55661240e+03,   2.92638367e-03],
        [  1.00000000e+00,   3.64729774e+03,   3.41396480e-03]],

       [[  0.00000000e+00,   6.01328590e+03,   7.58604321e-02],
        [  1.50000000e-01,   4.99142603e+03,   5.90153991e-02],
        [  3.00000000e-01,   5.37852580e+03,   6.85608073e-02],
        [  4.50000000e-01,   5.60092642e+03,   5.57529783e-02],
        [  6.00000000e-01,   5.28887052e+03,   7.95171109e-02],
        [  7.50000000e-01,   5.76688077e+03,   5.62868886e-02],
        [  9.00000000e-01,   5.64968420e+03,   6.18576364e-02],
        [  1.00000000e+00,   5.14956930e+03,   5.67060100e-02]]])

# %%
#S.fd
import numpy as np
results=np.array([[[  0.00000000e+00,   7.28896652e+02,   0.00000000e+00],
        [  5.00000000e-02,   5.93091595e+02,   0.00000000e+00],
        [  1.25000000e-01,   6.32614541e+02,   0.00000000e+00],
        [  2.00000000e-01,   6.05118249e+02,   0.00000000e+00],
        [  3.00000000e-01,   6.66852307e+02,   0.00000000e+00],
        [  5.00000000e-01,   6.93892703e+02,   0.00000000e+00]],

       [[  0.00000000e+00,   1.30734267e+03,   8.75895179e-01],
        [  5.00000000e-02,   1.35950167e+03,   9.26877265e-01],
        [  1.25000000e-01,   1.29549171e+03,   8.99198977e-01],
        [  2.00000000e-01,   1.33083673e+03,   8.41471619e-01],
        [  3.00000000e-01,   1.35229102e+03,   9.68842547e-01],
        [  5.00000000e-01,   1.46872550e+03,   1.04130309e+00]],

       [[  0.00000000e+00,   3.31234298e+03,   1.22855387e-02],
        [  5.00000000e-02,   3.34629609e+03,   1.30856349e-02],
        [  1.25000000e-01,   3.70622626e+03,   1.16165321e-02],
        [  2.00000000e-01,   3.75433301e+03,   1.23181247e-02],
        [  3.00000000e-01,   3.22549986e+03,   1.15733519e-02],
        [  5.00000000e-01,   3.44943460e+03,   1.30053932e-02]],

       [[  0.00000000e+00,   3.68782734e+03,   3.80519438e-03],
        [  5.00000000e-02,   3.64779570e+03,   3.42084619e-03],
        [  1.25000000e-01,   3.57290534e+03,   3.25928739e-03],
        [  2.00000000e-01,   3.53004019e+03,   2.99755091e-03],
        [  3.00000000e-01,   3.48904050e+03,   3.77885230e-03],
        [  5.00000000e-01,   3.47872737e+03,   3.96775975e-03]],

       [[  0.00000000e+00,   5.46623843e+03,   5.87534732e-02],
        [  5.00000000e-02,   5.17701155e+03,   7.11419663e-02],
        [  1.25000000e-01,   5.09616601e+03,   5.56241175e-02],
        [  2.00000000e-01,   5.23724731e+03,   6.62925099e-02],
        [  3.00000000e-01,   5.26794238e+03,   6.64676096e-02],
        [  5.00000000e-01,   5.56987298e+03,   6.55659910e-02]]])

# %%
#S.fe
import numpy as np
results=np.array([[[  0.00000000e+00,   2.66829130e+03,   0.00000000e+00],
        [  5.00000000e-02,   4.17826863e+02,   0.00000000e+00],
        [  1.00000000e-01,   4.52017554e+02,   0.00000000e+00],
        [  1.50000000e-01,   5.80321856e+02,   0.00000000e+00],
        [  2.00000000e-01,   8.10671489e+02,   0.00000000e+00],
        [  3.00000000e-01,   8.08925649e+02,   0.00000000e+00],
        [  4.00000000e-01,   7.33361969e+02,   0.00000000e+00],
        [  5.00000000e-01,   8.75194754e+02,   0.00000000e+00]],

       [[  0.00000000e+00,   2.37056054e+03,   2.32104679e+00],
        [  5.00000000e-02,   8.84298453e+02,   5.10719165e-01],
        [  1.00000000e-01,   9.62603812e+02,   5.72065719e-01],
        [  1.50000000e-01,   1.18360129e+03,   7.44399220e-01],
        [  2.00000000e-01,   1.23838311e+03,   8.89098180e-01],
        [  3.00000000e-01,   1.35926954e+03,   9.88444548e-01],
        [  4.00000000e-01,   1.73579329e+03,   1.14228785e+00],
        [  5.00000000e-01,   1.96830255e+03,   1.61268422e+00]],

       [[  0.00000000e+00,   2.24399557e+03,   2.73440176e-02],
        [  5.00000000e-02,   1.49947235e+03,   8.04621211e-03],
        [  1.00000000e-01,   1.88601288e+03,   8.35035200e-03],
        [  1.50000000e-01,   2.75944769e+03,   1.13706930e-02],
        [  2.00000000e-01,   3.44128991e+03,   1.21857258e-02],
        [  3.00000000e-01,   3.93819065e+03,   1.32689260e-02],
        [  4.00000000e-01,   4.60121528e+03,   1.72668983e-02],
        [  5.00000000e-01,   5.45121081e+03,   2.06998945e-02]],

       [[  0.00000000e+00,   3.17888621e+03,   1.08703403e-02],
        [  5.00000000e-02,   1.95907764e+03,   1.89010492e-03],
        [  1.00000000e-01,   2.55371031e+03,   2.33699088e-03],
        [  1.50000000e-01,   2.78829963e+03,   3.11579675e-03],
        [  2.00000000e-01,   3.90953554e+03,   3.49415978e-03],
        [  3.00000000e-01,   4.46428232e+03,   3.76646471e-03],
        [  4.00000000e-01,   4.88871446e+03,   4.65534821e-03],
        [  5.00000000e-01,   5.63155222e+03,   5.84951230e-03]],

       [[  0.00000000e+00,   3.73711893e+03,   1.91543308e-01],
        [  5.00000000e-02,   2.02655957e+03,   3.15081424e-02],
        [  1.00000000e-01,   2.88742673e+03,   4.46371463e-02],
        [  1.50000000e-01,   4.01738890e+03,   4.78877566e-02],
        [  2.00000000e-01,   5.33234041e+03,   6.00676402e-02],
        [  3.00000000e-01,   6.46296522e+03,   6.69083687e-02],
        [  4.00000000e-01,   7.57091015e+03,   7.45373298e-02],
        [  5.00000000e-01,   8.75257654e+03,   8.86983338e-02]]])

# %%
#S.a
import numpy as np
results=np.array([[[  5.00000000e-01,   4.57201217e+02,   0.00000000e+00],
        [  9.00000000e-01,   4.77536835e+02,   0.00000000e+00],
        [  1.20000000e+00,   5.09302904e+02,   0.00000000e+00],
        [  1.50000000e+00,   5.91200741e+02,   0.00000000e+00],
        [  1.98000000e+00,   5.84369526e+02,   0.00000000e+00]],

       [[  5.00000000e-01,   1.02231403e+03,   6.58657596e-01],
        [  9.00000000e-01,   1.14310705e+03,   7.22258472e-01],
        [  1.20000000e+00,   1.26558542e+03,   9.55385110e-01],
        [  1.50000000e+00,   1.03260304e+03,   6.04666048e-01],
        [  1.98000000e+00,   8.33529172e+02,   5.25038768e-01]],

       [[  5.00000000e-01,   2.14178009e+03,   8.99786472e-03],
        [  9.00000000e-01,   2.16740999e+03,   9.32858978e-03],
        [  1.20000000e+00,   2.21836496e+03,   1.18788795e-02],
        [  1.50000000e+00,   2.36579653e+03,   8.55837513e-03],
        [  1.98000000e+00,   2.33084817e+03,   6.70109842e-03]],

       [[  5.00000000e-01,   2.39034415e+03,   2.28479481e-03],
        [  9.00000000e-01,   2.25223085e+03,   2.76537457e-03],
        [  1.20000000e+00,   2.50777982e+03,   2.70816409e-03],
        [  1.50000000e+00,   2.73783650e+03,   2.47969930e-03],
        [  1.98000000e+00,   2.55350531e+03,   2.12723006e-03]],

       [[  5.00000000e-01,   3.17339983e+03,   4.37925801e-02],
        [  9.00000000e-01,   2.69148392e+03,   4.91931914e-02],
        [  1.20000000e+00,   2.89299286e+03,   3.74121683e-02],
        [  1.50000000e+00,   3.01849361e+03,   4.55614899e-02],
        [  1.98000000e+00,   3.02832196e+03,   3.93336016e-02]]])

# %%
#S.g
import numpy as np
results=np.array([[[  5.00000000e-01,   5.38834607e+02,   0.00000000e+00],
        [  1.00000000e+00,   5.13267002e+02,   0.00000000e+00],
        [  1.50000000e+00,   5.00067483e+02,   0.00000000e+00],
        [  2.00000000e+00,   4.10411043e+02,   0.00000000e+00],
        [  3.00000000e+00,   5.23290381e+02,   0.00000000e+00]],

       [[  5.00000000e-01,   9.07168893e+02,   4.71299001e-01],
        [  1.00000000e+00,   8.73199597e+02,   6.50182465e-01],
        [  1.50000000e+00,   1.00320721e+03,   6.69435121e-01],
        [  2.00000000e+00,   8.93342094e+02,   5.99589373e-01],
        [  3.00000000e+00,   9.91157172e+02,   5.53411681e-01]],

       [[  5.00000000e-01,   1.70280199e+03,   7.87497626e-03],
        [  1.00000000e+00,   2.73250312e+03,   9.14096053e-03],
        [  1.50000000e+00,   2.10179488e+03,   8.44186593e-03],
        [  2.00000000e+00,   2.27450878e+03,   7.69005892e-03],
        [  3.00000000e+00,   2.27096904e+03,   7.78970613e-03]],

       [[  5.00000000e-01,   2.03058393e+03,   2.59821204e-03],
        [  1.00000000e+00,   2.59941256e+03,   2.29877423e-03],
        [  1.50000000e+00,   2.25715172e+03,   2.48748625e-03],
        [  2.00000000e+00,   2.24524555e+03,   2.16471300e-03],
        [  3.00000000e+00,   2.27242049e+03,   2.13166440e-03]],

       [[  5.00000000e-01,   2.87029103e+03,   4.61523342e-02],
        [  1.00000000e+00,   2.68691288e+03,   2.76208515e-02],
        [  1.50000000e+00,   3.01806862e+03,   2.78879391e-02],
        [  2.00000000e+00,   3.32869218e+03,   3.58971244e-02],
        [  3.00000000e+00,   2.92339217e+03,   3.97898745e-02]]])

# %%
import sys
import os
sys.path.insert(0,os.path.abspath(os.path.join(os.path.abspath(os.getcwd()), os.pardir)))
import OptiPlot as op
label=['\\textbf{Eil51}','\\textbf{St70}','\\textbf{Pr107}','\\textbf{Bier127}','\\textbf{Ch150}']
title='\\textbf{Meta-Optimization of Gnowee Algorithm for Population Size (S.p)}'  #!!
op.Plot_Meta_Optimization(results,label,title)
# Out:
# C:\Users\James\Miniconda\lib\site-packages\matplotlib\axes\_base.py:2809: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=2686.91288, top=2686.91288
#   'bottom=%s, top=%s') % (bottom, top))
