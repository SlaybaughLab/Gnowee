# %%
# Population
from  HyperOpt import hyper_opt

results = hyper_opt(True, 'population', [10, 20, 30, 40, 60], 20)
# Out:
# tsp
# Run: eil51.tsp, population=10, iter# 0
# Stall at evaluation #137198
# Program execution time was 69.3269999027.
# Run: eil51.tsp, population=10, iter# 1
# Fitness Convergence
# Program execution time was 72.3340001106.
# Run: eil51.tsp, population=10, iter# 2
# Stall at evaluation #77240
# Program execution time was 124.786999941.
# Run: eil51.tsp, population=10, iter# 3
# Stall at evaluation #110740
# Program execution time was 121.054999828.
# Run: eil51.tsp, population=10, iter# 4
# Stall at evaluation #158100
# Program execution time was 220.543000221.
# Run: eil51.tsp, population=10, iter# 5
# Stall at evaluation #110040
# Program execution time was 154.88499999.
# Run: eil51.tsp, population=10, iter# 6
# Stall at evaluation #107400
# Program execution time was 151.323999882.
# Run: eil51.tsp, population=10, iter# 7
# Stall at evaluation #65580
# Program execution time was 92.9480001926.
# Run: eil51.tsp, population=10, iter# 8
# Stall at evaluation #91520
# ...
